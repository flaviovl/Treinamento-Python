# %%
# Programas básicos em Python - Perguntas de entrevista em Python
# 1. Escreva um programa em Python para executar o algoritmo Bubble Sort.

def bs(a):
    b=len(a)
    for x in range(b):
        for y in range(b-x):
            a[y]=a[y+1]

a=[32,5,3,6,7,54,87]
bs(a)
# Saída:  [3, 5, 6, 7, 32, 54, 87]

# 2. Escreva um programa em Python para produzir triângulo estrela.

def pyfunc(r):
    for x in range(r):
        print(' '*(r-x-1)+'*'*(2*x+1))    
pyfunc(9)

# Saída:
#         *
#        ***
#       *****
#      *******
#     *********
#    ***********
#   *************
#  ***************
# *****************

# 3. Escreva um programa para produzir séries de Fibonacci em Python.

a = int(input("Enter the terms"))
f = 0
s = 1
if a == 0:
    print("The requested series is",f)

else:
    print(f,s,end=" ")
    for x in range(2,a): 
        print(next,end=" ")
        f = s
        s = next

# Saída: Insira os termos 5 0 1 1 2 3

Q79. Escreva um programa em Python para verificar se um número é primo.

a=int(input("enter number"))
if a=1:
   for x in range(2,a):
         if(a%x)==0:
          print("not prime")
   break
   else:
      print("Prime")
else:
   print("not prime")
Saída:

digite o número 3

Melhor

Q80. Escreva um programa em Python para verificar se uma sequência é um Palíndromo.

a=input("enter sequence")
b=a[::-1]
if a==b:
  print("palindrome")
else:
  print("Not a Palindrome")
Saída:

digite a sequência 323 palíndromo

Q81. Escreva uma linha que conte o número de letras maiúsculas em um arquivo. Seu código deve funcionar mesmo que o arquivo seja muito grande para caber na memória.
Resposta:   Vamos primeiro escrever uma solução de várias linhas e depois convertê-la em código de uma linha.

with open(SOME_LARGE_FILE) as fh:
count = 0
text = fh.read()
for character in text:
    if character.isupper():
count += 1
Vamos agora tentar transformar isso em uma única linha.

1
count sum(1 for line in fh for character in line if character.isupper())
Q82. Escreva um algoritmo de classificação para um conjunto de dados numérico em Python.
Resp:  O código a seguir pode ser usado para classificar uma lista em Python:

list = ["1", "4", "0", "6", "9"]
list = [int(i) for i in list]
list.sort()
print (list)

# Q83. Observando o código abaixo, anote os valores finais de A0, A1, …An.

A0 = dict(zip(('a','b','c','d','e'),(1,2,3,4,5)))
A1 = range(10)A2 = sorted([i for i in A1 if i in A0])
A3 = sorted([A0[s] for s in A0])
A4 = [i for i in A1 if i in A3]
A5 = {i:i*i for i in A1}
A6 = [[i,i*i] for i in A1]
print(A0,A1,A2,A3,A4,A5,A6)

# Resp:  A seguir serão as saídas finais de A0, A1, … A6

A0 = {'a': 1, 'c': 3, 'b': 2, 'e': 5, 'd': 4} # a ordem pode variar
A1 = intervalo(0, 10)
A2 = []
A3 = [1, 2, 3, 4, 5]
A4 = [1, 2, 3, 4, 5]
A5 = {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
A6 = [[0, 0], [1, 1], [2, 4], [3, 9], [4, 16], [5, 25], [6, 36], [7, 49] , [8, 64], [9, 81]]

# Em seguida, nestas perguntas da entrevista em Python, vamos dar uma olhada em a
